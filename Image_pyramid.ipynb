# %%
import cv2
import numpy as np
img = cv2.imread('cr.jpg')
lower_reso = cv2.pyrDown(img)
higher_reso2 = cv2.pyrUp(img)
from google.colab.patches import cv2_imshow
cv2_imshow(lower_reso)
cv2_imshow(higher_reso2)
# Out:
# <PIL.Image.Image image mode=RGB size=330x186 at 0x7FA786F3EB00>
# <PIL.Image.Image image mode=RGB size=1320x742 at 0x7FA77DEBDB00>
